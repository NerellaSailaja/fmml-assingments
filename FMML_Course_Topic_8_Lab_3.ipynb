# %% [markdown]
# <a href="https://colab.research.google.com/github/NerellaSailaja/fmml-assingments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-01 14:10:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2023-05-01 14:10:25 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26796  1611.09010v1  This paper addresses the problem of 3D human p...    cs
# 1327    1412.3684v1  Recognition of objects using Deep Neural Netwo...    cs
# 8057    1110.3109v2  This paper presents a novel L1-norm semi-super...    cs
# 6308   1611.01957v3  SVRG and its variants are among the state of a...  stat
# 11772  1611.09621v1  An associative memory is a framework of conten...  stat
# ...             ...                                                ...   ...
# 30111  1711.07235v2  Hyperspectral imaging holds enormous potential...    cs
# 38001  1803.03166v1  In this paper, we introduce a new learning str...  stat
# 10448   1104.2930v3  With inspiration from Random Forests (RF) in t...  stat
# 28988  1708.01844v2  Facial wrinkle is one of the most prominent bi...    cs
# 25646  1511.00096v1  Visual motion estimation is a computationally ...    cs
#
#                                                    title  year  \
# 26796  3D Human Pose Estimation from a Single Image v...  2016
# 1327   Object Recognition Using Deep Neural Networks:...  2014
# 8057   Robust Image Analysis by L1-Norm Semi-supervis...  2011
# 6308   Linear Convergence of SVRG in Statistical Esti...  2016
# 11772  Associative Memory using Dictionary Learning a...  2016
# ...                                                  ...   ...
# 30111  Tracking in Aerial Hyperspectral Videos using ...  2017
# 38001           Aggregation using input-output trade-off  2018
# 10448                                    Cluster Forests  2011
# 28988  Automated Assessment of Facial Wrinkling: a ca...  2017
# 25646               Bioinspired Visual Motion Estimation  2015
#
#                                                 keywords
# 26796  [addresses, estimation, detecting, observation...
# 1327   [recognition, breakthroughs, progressed, descr...
# 8057   [supervised, algorithm, formulation, laplacian...
# 6308   [optimization, algorithms, converges, objectiv...
# 11772  [associative, framework, addressable, collecti...
# ...                                                  ...
# 30111  [hyperspectral, potential, resolutions, hypers...
# 38001  [introduce, mojirsheibani, combining, classifi...
# 10448  [inspiration, classification, clustering, geom...
# 28988  [prominent, biological, accompanying, contribu...
# 25646  [estimation, computationally, intensive, impor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26796    [addresses, estimation, detecting, observation...
# 1327     [recognition, breakthroughs, progressed, descr...
# 8057     [supervised, algorithm, formulation, laplacian...
# 6308     [optimization, algorithms, converges, objectiv...
# 11772    [associative, framework, addressable, collecti...
#                                ...
# 21930    [concentration, inequalities, probability, dis...
# 31465    [estimation, sophisticated, architectures, cap...
# 7687     [permutations, introduce, unequally, contribut...
# 18617    [addresses, uncertainty, processes, represent,...
# 2813     [processes, distributions, functions, generali...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8853 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5f7452da-86f0-418e-890b-77e1dfccd530" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f7452da-86f0-418e-890b-77e1dfccd530")) {                    Plotly.newPlot(                        "5f7452da-86f0-418e-890b-77e1dfccd530",                        [{"x":["regressor","performance","addresses","evaluation","positivity","generalization","demonstrate","architectures","promising","observations","approaches","detecting","estimates","representing","formulating","coordinates","construction","regression","predicted","estimation","consistent","hypothesize","advantage","cartesian","quantitative","naturally","qualitative","benchmark","recognition","breakthroughs","performances","tabulated","algorithm","describes","applications","progressed","developed","experimental","formulation","refinement","effectively","reconstruction","supervised","important","regularization","successfully","representation","laplacian","normalized","classification","reduction","formulate","particular","eigenvectors","algorithms","estimators","formulations","restricted","convexity","difference","parameter","restrictive","optimization","convergence","statistical","converges","mentioned","including","corrected","precision","objective","fundamental","respectively","addressing","addressable","mechanism","collection","designing","graphical","correction","iterative","specifically","adversarial","dictionary","associative","containing","framework","distributions","iteration","constructs","considering","procedure","marginals","additionally","accelerated","parameters","propagation","adaptively","complexity","continuous","computational","particles","mcallester","empirically","expectation","exponential","efficient","approximating","quadratic","implementation","increases","dramatically","automatically","statistics","superiority","identification","undesirable","environment","stability","characteristic","introduce","unfortunately","requirement","emphasize","splitting","partially","counterpart","nonlinear","experiments","strategies","operating","analytical","reproducing","appropriate","demonstrated","discarding","filtering","interpreted","competitive","maximization","significant","aggregation","principle","effective","maintaining","validation","involving","adjectives","distributed","hypernyms","following","unsupervised","empirical","properties","indicates","classifier","convolutional","tensorflow","nonlinearity","contribution","architecture","increasing","progressively","separation","contraction","available","reproducible","clusterings","frequently","bipartite","decomposition","distances","structure","component","different","comparing","clustering","components","coreference","information","resolution","conditionally","consistency","traditional","conditioning","linguistic","engineered","templates","utterances","sequences","interpretable","competitively","attention","representations","reliability","improving","robustness","classifiers","discovering","rejection"],"y":[7,861,48,270,2,100,571,122,130,88,452,72,73,87,7,17,67,118,50,196,76,10,106,3,77,64,66,224,407,6,45,1,810,84,432,2,208,345,85,25,117,94,205,357,88,84,364,18,27,521,93,51,262,9,601,10,14,53,15,57,104,4,304,126,143,26,12,219,7,76,157,74,97,17,1,107,76,40,46,19,82,186,105,44,8,48,509,100,39,23,67,123,4,77,17,215,74,20,229,112,304,4,0,63,39,41,400,16,38,119,47,25,183,48,39,118,9,123,30,23,322,29,28,12,7,45,15,68,621,98,25,24,11,75,94,3,72,22,111,37,247,25,54,225,36,47,52,6,104,2,69,164,163,213,26,148,397,4,5,84,273,97,12,32,3,283,3,4,26,6,68,32,339,98,748,69,145,118,9,711,142,7,49,173,10,78,9,6,16,106,26,5,179,255,31,107,88,127,35,10],"type":"bar"},{"x":["regressor","performance","addresses","evaluation","positivity","generalization ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Body</span> <span style=''>Part</span> <span style='background-color:rgba(255, 0, 0, 0.5021097046413502);'>Regression</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Spatially</span> <span style=''>Self</span> <span style=''>ordering</span> <span style='background-color:rgba(0, 255, 0, 0.6473029045643154);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.6033057851239669);'>Automatic</span> <span style=''>body</span> <span style=''>part</span> <span style='background-color:rgba(0, 255, 0, 0.6378269617706238);'>recognition</span> <span style=''>for</span> <span style=''>CT</span> <span style=''>slices</span> <span style=''>can</span> <span style=''>benefit</span> <span style=''>various</span> <span style=''>medical</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>Recent</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(0, 255, 0, 0.4130434782608696);'>promising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3023255813953489);'>requirement</span> <span style=''>of</span> <span style=''>large</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>images</span> <span style=''>for</span> <span style=''>training</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3246753246753246);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>or</span> <span style=''>superior</span> <span style=''>inferior</span> <span style=''>slice</span> <span style=''>ordering</span> <span style='background-color:rgba(0, 255, 0, 0.306985294117647);'>information</span> <span style=''>in</span> <span style=''>CT</span> <span style=''>volumes</span> <span style=''>is</span> <span style=''>not</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.35714285714285715);'>exploited</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6473029045643154);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Body</span> <span style=''>part</span> <span style='background-color:rgba(255, 0, 0, 0.5021097046413502);'>Regression</span> <span style=''>(UBR)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>and</span> <span style=''>two</span> <span style=''>inter</span> <span style=''>sample</span> <span style=''>CNN</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3712121212121212);'>presented</span> <span style=''>Distinct</span> <span style=''>from</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>UBR</span> <span style=''>builds</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.408450704 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>Belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>fixed</span> <span style=''>points</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>physics</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>over</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>Belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>message</span> <span style=''>passing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>computes</span> <span style=''>exactly</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginals</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>But</span> <span style=''>it</span> <span style=''>has</span> <span style=''>gained</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>them</span> <span style=''>in</span> <span style=''>the</span> <span style=''>more</span> <span style=''>general</span> <span style=''>case</span> <span style=''>even</span> <span style=''>if</span> <span style=''>it</span> <span style=''>can</span> <span style=''>exhibits</span> <span style=''>multiple</span> <span style=''>fixed</span> <span style=''>points</span> <span style=''>and</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>express</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>for</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>a</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>fixed</span> <span style=''>point</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>the</span> <span style=''>beliefs</span> <span style=''>values</span> <span style=''>at</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Modular</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Adaptive</span> <span style=''>(Non</span> <span style=''>)Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>Optimism</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Composite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Objectives</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5289855072463767);'>Variational</span> <span style=''>Bounds</span> <br/><br/><span style=''>Recently</span> <span style=''>much</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>scope</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style='background-color:rgba(255, 0, 0, 0.3586698337292162);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521746);'>contribute</span> <span style=''>to</span> <span style=''>this</span> <span style=''>effort</span> <span style=''>in</span> <span style=''>two</span> <span style=''>ways</span> <span style=''>First</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>new</span> <span style=''>regret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divergences</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contained</span> <span style=''>modular</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style=''>workhorses</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>(general)</span> <span style=''>adaptive</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>Mirror</span> <span style=''>Descent</span> <span style=''>(MD)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Follow</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>Regularized</span> <span style=''>Leader</span> <span style=''>(FTRL)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>The</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>done</span> <span style=''>with</span> <span style=''>extra</span> <span style=''>care</span> <span style=''>so</span> <span style=''>as</span> <span style=''>not</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>not</span> <span style=''>needed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>proofs</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>straightforward</span> <span style=''>way</span> <span style='background-color:rgba(0, 255, 0, 0.315 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>scores</span> <span style=''>and</span> <span style=''>lossless</span> <span style=''>feature</span> <span style=''>pruning</span> <span style=''>using</span> <span style=''>Banzhaf</span> <span style=''>power</span> <span style=''>indices</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>features</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreting</span> <span style=''>models</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>the</span> <span style=''>best</span> <span style=''>features</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>from</span> <span style=''>coalitional</span> <span style=''>game</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>reason</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>features</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Banzhaf</span> <span style=''>power</span> <span style=''>index</span> <span style=''>as</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>features</span> <span style=''>on</span> <span style=''>the</span> <span style=''>outcome</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>features</span> <span style=''>having</span> <span style=''>Banzhaf</span> <span style=''>power</span> <span style=''>index</span> <span style=''>of</span> <span style=''>zero</span> <span style=''>can</span> <span style=''>be</span> <span style=''>losslessly</span> <span style=''>pruned</span> <span style=''>without</span> <span style=''>damage</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computing</span> <span style=''>the</span> <span style=''>power</span> <span style=''>indices</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>having</span> <span style=''>access</span> <span style=''>to</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>However</span> <span style=''>if</span> <span style=''>samples</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>the</span> <span style=''>indices</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>We</span> <span style=''>compute</span> <span style=''>Banzhaf</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.0967741935483871)
# 	representation (0.13046594982078852)
# 	knowledge (0.12903225806451613)
# 	processing (0.10681003584229391)
# 	architecture (0.0978494623655914)
# 	information (0.25483870967741934)
# 	detection (0.12473118279569892)
# 	different (0.26810035842293906)
# 	convolutional (0.14229390681003584)
# 	recognition (0.14587813620071685)
#
# Some Statistics words are:
# 	algorithm (0.3781094527363184)
# 	distributions (0.12388059701492538)
# 	stochastic (0.14228855721393036)
# 	variables (0.14129353233830846)
# 	theoretical (0.15771144278606966)
# 	estimation (0.1771144278606965)
# 	distribution (0.1845771144278607)
# 	inference (0.20049751243781094)
# 	dimensional (0.18507462686567164)
# 	regression (0.1771144278606965)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9341036e-f2c4-480d-a689-598aded2fd6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9341036e-f2c4-480d-a689-598aded2fd6d")) {                    Plotly.newPlot(                        "9341036e-f2c4-480d-a689-598aded2fd6d",                        [{"x":["regressor","performance","addresses","evaluation","positivity","generalization","demonstrate","architectures","promising","observations","approaches","detecting","estimates","representing","formulating","coordinates","construction","regression","predicted","estimation","consistent","hypothesize","advantage","cartesian","quantitative","naturally","qualitative","benchmark","recognition","breakthroughs","performances","tabulated","algorithm","describes","applications","progressed","developed","experimental","formulation","refinement","effectively","reconstruction","supervised","important","regularization","successfully","representation","laplacian","normalized","classification","reduction","formulate","particular","eigenvectors","algorithms","estimators","formulations","restricted","convexity","difference","parameter","restrictive","optimization","convergence","statistical","converges","mentioned","including","corrected","precision","objective","fundamental","respectively","addressing","addressable","mechanism","collection","designing","graphical","correction","iterative","specifically","adversarial","dictionary","associative","containing","framework","distributions","iteration","constructs","considering","procedure","marginals","additionally","accelerated","parameters","propagation","adaptively","complexity","continuous","computational","particles","mcallester","empirically","expectation","exponential","efficient","approximating","quadratic","implementation","increases","dramatically","automatically","statistics","superiority","identification","undesirable","environment","stability","characteristic","introduce","unfortunately","requirement","emphasize","splitting","partially","counterpart","nonlinear","experiments","strategies","operating","analytical","reproducing","appropriate","demonstrated","discarding","filtering","interpreted","competitive","maximization","significant","aggregation","principle","effective","maintaining","validation","involving","adjectives","distributed","hypernyms","following","unsupervised","empirical","properties","indicates","classifier","convolutional","tensorflow","nonlinearity","contribution","architecture","increasing","progressively","separation","contraction","available","reproducible","clusterings","frequently","bipartite","decomposition","distances","structure","component","different","comparing","clustering","components","coreference","information","resolution","conditionally","consistency","traditional","conditioning","linguistic","engineered","templates","utterances","sequences","interpretable","competitively","attention","representations","reliability","improving","robustness","classifiers","discovering","rejection","application","correcting","effectiveness","overfitting","mathematically","translates","feedforward","formalism","motivated","techniques","resources","transform","considered","theoretically","multilayer","rationality","theoretic","transmission","scenarios","handwritten","knowledge","intelligence","determine","threshold","uniformly","laboratory","probability","interactive","experiment","emergence","conditions","consistently","geometric","industrial","simulated","improvements","theoretical","utilizing","demonstrates","suggesting","linearnonlinear","efficiency","outperform","predictor","relationship","underlying","independence","previously","conditional","connected","individual","correctly","interested","providing","construct","collabora ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	mcallester
# 	linearnonlinear
# 	adjustments
# 	integrable
# 	complemented
# 	penalization
# 	poisoning
# 	detectability
# 	supersparse
# 	reassignment
# 	couplings
# 	complicates
# 	psychiatric
# 	schizophrenia
# 	heteroskedastic
# 	parameterizes
# 	coherently
# 	sparsistent
# 	incrementalonline
# 	unavailability
# Some words which never appear in Statistics papers:
# 	progressed
# 	adjectives
# 	hypernyms
# 	coreference
# 	foregrounds
# 	asynchronized
# 	satellites
# 	concluded
# 	sharpening
# 	recurrently
# 	sequentiality
# 	propositional
# 	connectives
# 	passwords
# 	broadcast
# 	neuroevolution
# 	vectorized
# 	workflows
# 	vectorization
# 	scribbles

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079291762894534e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
